# %%
from rembg.bg import remove
from PIL import Image

# %%
input_path = './mops.png'
output_path = './mops_without_bg.png'

input = Image.open(input_path)
output = remove(input)
output.save(output_path)

# %%
import io
output_bytes = io.BytesIO()
type(output_bytes)
# Out:
# _io.BytesIO

# %%
import cv2 as cv
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil_img = Image.open('samples/kitten.png')
pil_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=350x450>

# %%
arr_img = np.asarray(pil_img)
arr_img = cv.cvtColor(arr_img, cv.COLOR_RGB2BGR)
plt.imshow(arr_img)
pil_img = Image.fromarray(arr_img)
pil_img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=350x450>

# %%
import utils
