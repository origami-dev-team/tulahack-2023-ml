# %%
import io
from PIL import Image
from torch import load
from utils import generate_image

model = load('./pretrained_models/generating_model.pth')

# %%
prompt = 'домик в соснах'
img_bytes = generate_image(prompt, model, False, False)
image = Image.open(io.BytesIO(img_bytes[0]))
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 19.43it/s]

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=350x450>
